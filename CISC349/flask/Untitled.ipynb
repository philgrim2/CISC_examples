# %%
import stdio

while True:
    try:
        foo = stdio.readInt()
        if foo < :
            stdio.writeln("That's the wrong number")
        else:
            break
    except:
        stdio.writeln("That's not a number")
        
stdio.writeln("You said " + str(foo))
# Out:
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# That's not a number
# ...
