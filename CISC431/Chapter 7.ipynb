# %%
import nltk, re, pprint

def ie_preprocess(document):
    sentences = nltk.sent_tokenize(document) 
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    sentences = [nltk.pos_tag(sent) for sent in sentences]

# %%
sentence = [("the", "DT"), ("little", "JJ"), ("yellow", "JJ"),
 ("dog", "NN"), ("barked", "VBD"), ("at", "IN"),  ("the", "DT"), ("cat", "NN")]

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"

cp = nltk.RegexpParser(grammar)
result = cp.parse(sentence)
print(result)
# Out:
# (S
#   (NP the/DT little/JJ yellow/JJ dog/NN)
#   barked/VBD
#   at/IN
#   (NP the/DT cat/NN))

# %%
result.draw()

# %%
nltk.app.chunkparser()

# %%
text = '''
he PRP B-NP
accepted VBD B-VP
the DT B-NP
position NN I-NP
of IN B-PP
vice NN B-NP
chairman NN I-NP
of IN B-PP
Carlyle NNP B-NP
Group NNP I-NP
, , O
a DT B-NP
merchant NN I-NP
banking NN I-NP
concern NN I-NP
. . O
'''

# %%
nltk.chunk.conllstr2tree(text, chunk_types=['NP']).draw()

# %%
from nltk.corpus import conll2000
cp = nltk.RegexpParser("")
test_sents = conll2000.chunked_sents('test.txt', chunk_types=['NP'])
print(cp.accuracy(test_sents))
# Out:
# ChunkParse score:
#     IOB Accuracy:  43.4%%
#     Precision:      0.0%%
#     Recall:         0.0%%
#     F-Measure:      0.0%%

# %%
grammar = r"NP: {<[CDJNP].*>+}"
cp = nltk.RegexpParser(grammar)
chunkscore = cp.accuracy(test_sents)
print(chunkscore)
print(chunkscore.missed())
print(chunkscore.incorrect())
# Out:
# ChunkParse score:
#     IOB Accuracy:  87.7%%
#     Precision:     70.6%%
#     Recall:        67.8%%
#     F-Measure:     69.2%%
# [ImmutableTree('NP', [('that', 'WDT')]), ImmutableTree('NP', [('the', 'DT'), ('Fed', 'NNP')]), ImmutableTree('NP', [('$', '$'), ('81', 'CD')]), ImmutableTree('NP', [('1.82', 'CD'), ('%', 'NN')]), ImmutableTree('NP', [("'s", 'POS'), ('name', 'NN')]), ImmutableTree('NP', [('the', 'DT'), ('deliberations', 'NNS')]), ImmutableTree('NP', [('there', 'EX')]), ImmutableTree('NP', [('most', 'RBS'), ('domestic', 'JJ'), ('airline', 'NN'), ('flights', 'NNS')]), ImmutableTree('NP', [('most', 'RBS'), ('junk', 'NN'), ('bonds', 'NNS')]), ImmutableTree('NP', [('operating', 'VBG'), ('profit', 'NN')]), ImmutableTree('NP', [('transfers', 'NNS')]), ImmutableTree('NP', [('who', 'WP')]), ImmutableTree('NP', [('A-2', 'NN'), ('preferred', 'JJ'), ('stock', 'NN')]), ImmutableTree('NP', [('wide', 'JJ'), ('fluctuations', 'NNS')]), ImmutableTree('NP', [('Afghans', 'NNPS')]), ImmutableTree('NP', [('85', 'CD'), ('%', 'NN')]), ImmutableTree('NP', [('$', '$'), ('317.7', 'CD'), ('million', 'CD')]), ImmutableTree('NP', [('futures-related', 'JJ'), ('program', 'NN'), ('selling', 'VBG')]), ImmutableTree('NP', [('80,000', 'CD'), ('miles', 'NNS')]), ImmutableTree('NP', [("'s", 'POS'), ('profit', 'NN')]), ImmutableTree('NP', [("'s", 'POS'), ('permission', 'NN')]), ImmutableTree('NP', [('chairman', 'NN')]), ImmutableTree('NP', [('chief', 'JJ'), ('operating', 'VBG'), ('officer', 'NN')]), ImmutableTree('NP', [('Mr.', 'NNP'), ('Bush', 'NNP')]), ImmutableTree('NP', [('not', 'RB'), ('all', 'PDT'), ('these', 'DT'), ('forces', 'NNS')]), ImmutableTree('NP', [('the', 'DT'), ('resistance', 'NN')]), ImmutableTree('NP', [('a', 'DT'), ('$', '$'), ('375,000', 'CD'), ('bonus', 'NN')]), ImmutableTree('NP', [('the', 'DT'), ('latest', 'JJS'), ('sign', 'NN')]), ImmutableTree('NP', [('that', 'WDT')]), ImmutableTree('NP', [('a', 'DT'), ('share', 'NN')]), ImmutableTree('NP', [('Alaska', 'NNP'), ('Air', 'NNP'), ('Group', 'NNP')]), ImmutableTree('NP', [('163', 'CD'), ('million', 'CD')]), ImmutableTree('NP', [('that', 'WDT')]), ImmutableTree('NP', [('Jaguar', 'NNP')]), ImmutableTree('NP', [('that', 'WDT')]), ImmutableTree('NP', [("'s", 'POS'), ('gyrations', 'NNS')]), ImmutableTree('NP', [('who', 'WP')]), ImmutableTree('NP', [('that', 'WDT')]), ImmutableTree('NP', [('U.S.', 'NNP')]), ImmutableTree('NP', [('$', '$'), ('1.6', 'CD'), ('billion', 'CD')]), ImmutableTree('NP', [('the', 'DT'), ('creditors', 'NNS')]), ImmutableTree('NP', [("'s", 'POS'), ('original', 'JJ'), ('vision', 'NN')]), ImmutableTree('NP', [("'s", 'POS'), ('second', 'JJ'), ('largest', 'JJS'), ('cable', 'NN'), ('operator', 'NN')]), ImmutableTree('NP', [('``', '``'), ('concrete', 'JJ'), ("''", "''"), ('talks', 'NNS')]), ImmutableTree('NP', [("'s", 'POS'), ('funds', 'NNS')]), ImmutableTree('NP', [('P&G', 'NNP')]), ImmutableTree('NP', [('whose', 'WP$'), ('$', '$'), ('62-a-share', 'JJ'), ('bid', 'NN')]), ImmutableTree('NP', [('approved', 'VBD'), ('countries', 'NNS')]), ImmutableTree('NP', [('$', '$'), ('36.3', 'CD'), ('million', 'CD')]), ImmutableTree('NP', [('the', 'DT'), ('growing', 'VBG'), ('U.S.', 'NNP'), ('interest', 'NN')]), ImmutableTree('NP', [('agent', 'NN')]), ImmutableTree('NP', [('tobacco', 'NN'), ('consumption', 'NN'), ('and', 'CC'), ('lung-cancer', 'NN'), ('mortality', 'NN'), ('rates', 'NNS')]), ImmutableTree('NP', [('which', 'WDT')]), ImmutableTree('NP', [('8.01', 'CD'), ('%', 'NN')]), ImmutableTree('NP', [('who', 'WP')]), ImmutableTree('NP', [('The', 'DT'), ('network', 'NN')]), ImmutableTree('NP', [('more', 'JJR'), ('than', 'IN'), ('25', 'CD'), ('%', 'NN'), ('casualties', 'NNS')]), ImmutableTree('NP', [('that', 'WDT')]), ImmutableTree('NP', [('currently', 'RB'), ('4.5', 'CD'), ('%', 'NN')]), ImmutableTree('NP', [('Homeowner', 'NNP')]), ImmutableTree('NP', [('Mr.', 'NNP'), ('Noriega', 'NNP')]), ImmutableTree('NP', [("'s", 'POS'), ('attempt', 'NN')]), ImmutableTree('NP', [('an', 'DT'), ('investment', 'NN'), ('banker', 'NN')]), ImmutableTree('NP', [('there', 'EX')]), ImmutableTree('NP', [('last', 'JJ'), ('August', 'NNP')]) ...
# [ImmutableTree('NP', [('his', 'PRP$')]), ImmutableTree('NP', [('and', 'CC'), ('a', 'DT')]), ImmutableTree('NP', [('talks', 'NNS')]), ImmutableTree('NP', [('Volume', 'NN'), ('224,070,000', 'CD'), ('shares', 'NNS')]), ImmutableTree('NP', [('the', 'DT'), ('Cubans', 'NNPS'), ('or', 'CC'), ('others', 'NNS')]), ImmutableTree('NP', [('the', 'DT')]), ImmutableTree('NP', [('Moscow', 'NNP'), ('free', 'JJ')]), ImmutableTree('NP', [('a', 'DT'), ('year', 'NN'), ('and', 'CC')]), ImmutableTree('NP', [('disappointment', 'NN'), ('many', 'JJ'), ('Indians', 'NNPS')]), ImmutableTree('NP', [('But', 'CC'), ('the', 'DT'), ('Tax', 'NNP'), ('Court', 'NNP')]), ImmutableTree('NP', [('either', 'DT')]), ImmutableTree('NP', [('two', 'CD'), ('years', 'NNS'), ('or', 'CC'), ('24,000', 'CD'), ('miles', 'NNS')]), ImmutableTree('NP', [('and', 'CC')]), ImmutableTree('NP', [('the', 'DT'), ('country', 'NN'), ("'s", 'POS'), ('central', 'JJ'), ('bank', 'NN')]), ImmutableTree('NP', [('the', 'DT'), ('next', 'JJ'), ('two', 'CD')]), ImmutableTree('NP', [('open', 'JJ'), ('his', 'PRP$'), ('trench', 'NN'), ('coat', 'NN')]), ImmutableTree('NP', [('many', 'JJ'), ('weeks', 'NNS')]), ImmutableTree('NP', [('vehicles', 'NNS')]), ImmutableTree('NP', [('600,000', 'CD')]), ImmutableTree('NP', [('liquid', 'JJ')]), ImmutableTree('NP', [('and', 'CC'), ('Merrill', 'NNP'), ('Lynch', 'NNP')]), ImmutableTree('NP', [('analysts', 'NNS'), ("'", 'POS'), ('expectations', 'NNS')]), ImmutableTree('NP', [('the', 'DT'), ('State', 'NNP'), ('Department', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('CIA', 'NNP')]), ImmutableTree('NP', [('Republic', 'NNP'), ('Airlines', 'NNPS'), ('and', 'CC'), ('Flying', 'NNP'), ('Tiger', 'NNP')]), ImmutableTree('NP', [('But', 'CC'), ('the', 'DT'), ('club', 'NN')]), ImmutableTree('NP', [('85', 'CD'), ('million', 'CD')]), ImmutableTree('NP', [('Capitol', 'NNP'), ('Hill', 'NNP'), ('last', 'JJ'), ('week', 'NN')]), ImmutableTree('NP', [('American', 'NNP'), ('Continental', 'NNP')]), ImmutableTree('NP', [('taxes', 'NNS'), ('and', 'CC'), ('interest', 'NN'), ('costs', 'NNS')]), ImmutableTree('NP', [('Canada', 'NNP'), ('and', 'CC'), ('Japan', 'NNP')]), ImmutableTree('NP', [('and', 'CC'), ('it', 'PRP')]), ImmutableTree('NP', [('Hugo', 'NNP'), ("'s", 'POS'), ('victims', 'NNS')]), ImmutableTree('NP', [('women', 'NNS'), ('he', 'PRP')]), ImmutableTree('NP', [('point', 'NN')]), ImmutableTree('NP', [('Continental', 'NNP'), ('and', 'CC'), ('Eastern', 'NNP'), ('airlines', 'NNS')]), ImmutableTree('NP', [('Spaced', 'NNP')]), ImmutableTree('NP', [('10,000', 'CD'), ('UAL', 'NNP'), ('shares', 'NNS'), ('and', 'CC')]), ImmutableTree('NP', [('available', 'JJ')]), ImmutableTree('NP', [('trades', 'NNS')]), ImmutableTree('NP', [('or', 'CC')]), ImmutableTree('NP', [('But', 'CC'), ('the', 'DT'), ('government', 'NN')]), ImmutableTree('NP', [('available', 'JJ')]), ImmutableTree('NP', [('712', 'CD'), ('million', 'CD')]), ImmutableTree('NP', [('400', 'CD'), ('monthly', 'JJ')]), ImmutableTree('NP', [('one', 'CD'), ('day', 'NN'), ('the', 'DT'), ('Swedish', 'JJ'), ('concern', 'NN'), ("'s", 'POS'), ('tender', 'NN'), ('offer', 'NN')]), ImmutableTree('NP', [('reluctant', 'JJ')]), ImmutableTree('NP', [('half', 'NN')]), ImmutableTree('NP', [('49', 'CD'), ('million', 'CD')]), ImmutableTree('NP', [('him', 'PRP'), ('he', 'PRP')]), ImmutableTree('NP', [('100,000', 'CD')]), ImmutableTree('NP', [('24.875', 'CD')]), ImmutableTree('NP', [('futures', 'NNS'), ('contracts', 'NNS')]), ImmutableTree('NP', [('veterans', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('environment', 'NN')]), ImmutableTree('NP', [('but', 'CC'), ('he', 'PRP')]), ImmutableTree('NP', [('Friday', 'NNP'), ("'s", 'POS'), ('market', 'NN'), ('bombshell', 'NN')]), ImmutableTree('NP', [('credit', 'NN'), ('and', 'CC'), ('lower', 'JJR'), ('interest', 'NN'), ('rates', 'NNS')]), ImmutableTree('NP', [('15.80', 'CD')]), ImmutableTree('NP', [('two', 'CD'), ('or', 'CC'), ('three', 'CD'), ('other', 'JJ'), ('major', 'JJ'), ('banks', 'NNS')]), ImmutableTree('NP', [('unhappy', ' ...

# %%
class UnigramChunker(nltk.ChunkParserI):
    def __init__(self, train_sents): # [_code-unigram-chunker-constructor]
        train_data = [[(t,c) for w,t,c in nltk.chunk.tree2conlltags(sent)]
                      for sent in train_sents]
        self.tagger = nltk.UnigramTagger(train_data) # [_code-unigram-chunker-buildit]

    def parse(self, sentence): # [_code-unigram-chunker-parse]
        pos_tags = [pos for (word,pos) in sentence]
        tagged_pos_tags = self.tagger.tag(pos_tags)
        chunktags = [chunktag for (pos, chunktag) in tagged_pos_tags]
        conlltags = [(word, pos, chunktag) for ((word,pos),chunktag)
                     in zip(sentence, chunktags)]
        return nltk.chunk.conlltags2tree(conlltags)

# %%
test_sents = conll2000.chunked_sents('test.txt', chunk_types=['NP'])
train_sents = conll2000.chunked_sents('train.txt', chunk_types=['NP'])
unigram_chunker = UnigramChunker(train_sents)
print(unigram_chunker.accuracy(test_sents))
# Out:
# ChunkParse score:
#     IOB Accuracy:  92.9%%
#     Precision:     79.9%%
#     Recall:        86.8%%
#     F-Measure:     83.2%%

# %%
sent = nltk.corpus.treebank.tagged_sents()
print(nltk.ne_chunk(sent, binary=True))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 sent = nltk.corpus.treebank.tagged_sents()
# ----> 2 print(nltk.ne_chunk(sent, binary=True))
#
# File ~\anaconda3\Lib\site-packages\nltk\chunk\__init__.py:184, in ne_chunk(tagged_tokens, binary)
#     182     chunker_pickle = _MULTICLASS_NE_CHUNKER
#     183 chunker = load(chunker_pickle)
# --> 184 return chunker.parse(tagged_tokens)
#
# File ~\anaconda3\Lib\site-packages\nltk\chunk\named_entity.py:127, in NEChunkParser.parse(self, tokens)
#     123 def parse(self, tokens):
#     124     """
#     125     Each token should be a pos-tagged word
#     126     """
# --> 127     tagged = self._tagger.tag(tokens)
#     128     tree = self._tagged_to_parse(tagged)
#     129     return tree
#
# File ~\anaconda3\Lib\site-packages\nltk\tag\sequential.py:61, in SequentialBackoffTagger.tag(self, tokens)
#      59 tags = []
#      60 for i in range(len(tokens)):
# ---> 61     tags.append(self.tag_one(tokens, i, tags))
#      62 return list(zip(tokens, tags))
#
# File ~\anaconda3\Lib\site-packages\nltk\tag\sequential.py:81, in SequentialBackoffTagger.tag_one(self, tokens, index, history)
#      79 tag = None
#      80 for tagger in self._taggers:
# ---> 81     tag = tagger.choose_tag(tokens, index, history)
#      82     if tag is not None:
#      83         break
#
# File ~\anaconda3\Lib\site-packages\nltk\tag\sequential.py:647, in ClassifierBasedTagger.choose_tag(self, tokens, index, history)
#     645 def choose_tag(self, tokens, index, history):
#     646     # Use our feature detector to get the featureset.
# --> 647     featureset = self.feature_detector(tokens, index, history)
#     649     # Use the classifier to pick a tag.  If a cutoff probability
#     650     # was specified, then check that the tag's probability is
#     651     # higher than that cutoff first; otherwise, return None.
#     652     if self._cutoff_prob is None:
#
# File ~\anaconda3\Lib\site-packages\nltk\tag\sequential.py:694, in ClassifierBasedTagger.feature_detector(self, tokens, index, history)
#     684 def feature_detector(self, tokens, index, history):
#     685     """
#     686     Return the feature detector that this tagger uses to generate
#     687     featuresets for its classifier.  The feature detector is a
#    (...)
#     692     See ``classifier()``
#     693     """
# --> 694     return self._feature_detector(tokens, index, history)
#
# File ~\anaconda3\Lib\site-packages\nltk\chunk\named_entity.py:58, in NEChunkParserTagger._feature_detector(self, tokens, index, history)
#      56 def _feature_detector(self, tokens, index, history):
#      57     word = tokens[index][0]
# ---> 58     pos = simplify_pos(tokens[index][1])
#      59     if index == 0:
#      60         prevword = prevprevword = None
#
# File ~\anaconda3\Lib\site-packages\nltk\chunk\named_entity.py:191, in simplify_pos(s)
#     190 def simplify_pos(s):
# --> 191     if s.startswith("V"):
#     192         return "V"
#     193     else:
#
# AttributeError: 'tuple' object has no attribute 'startswith'

# %%
IN = re.compile(r'.*\bin\b(?!\b.+ing)')
for doc in nltk.corpus.ieer.parsed_docs('NYT_19980315'):
     for rel in nltk.sem.extract_rels('ORG', 'LOC', doc,
                                      corpus='ieer', pattern = IN):
            print(nltk.sem.rtuple(rel))
# Out:
# [ORG: 'WHYY'] 'in' [LOC: 'Philadelphia']
# [ORG: 'McGlashan &AMP; Sarrail'] 'firm in' [LOC: 'San Mateo']
# [ORG: 'Freedom Forum'] 'in' [LOC: 'Arlington']
# [ORG: 'Brookings Institution'] ', the research group in' [LOC: 'Washington']
# [ORG: 'Idealab'] ', a self-described business incubator based in' [LOC: 'Los Angeles']
# [ORG: 'Open Text'] ', based in' [LOC: 'Waterloo']
# [ORG: 'WGBH'] 'in' [LOC: 'Boston']
# [ORG: 'Bastille Opera'] 'in' [LOC: 'Paris']
# [ORG: 'Omnicom'] 'in' [LOC: 'New York']
# [ORG: 'DDB Needham'] 'in' [LOC: 'New York']
# [ORG: 'Kaplan Thaler Group'] 'in' [LOC: 'New York']
# [ORG: 'BBDO South'] 'in' [LOC: 'Atlanta']
# [ORG: 'Georgia-Pacific'] 'in' [LOC: 'Atlanta']
